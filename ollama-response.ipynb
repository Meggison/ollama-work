# %%
# !pip install --upgrade pip
# !pip install ollama
# Out:
# Requirement already satisfied: pip in ./.venv/lib/python3.13/site-packages (26.0.1)
# Requirement already satisfied: ollama in ./.venv/lib/python3.13/site-packages (0.6.1)
# Requirement already satisfied: httpx>=0.27 in ./.venv/lib/python3.13/site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in ./.venv/lib/python3.13/site-packages (from ollama) (2.12.5)
# Requirement already satisfied: anyio in ./.venv/lib/python3.13/site-packages (from httpx>=0.27->ollama) (4.12.1)
# Requirement already satisfied: certifi in ./.venv/lib/python3.13/site-packages (from httpx>=0.27->ollama) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.13/site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in ./.venv/lib/python3.13/site-packages (from httpx>=0.27->ollama) (3.11)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.13/site-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./.venv/lib/python3.13/site-packages (from pydantic>=2.9->ollama) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in ./.venv/lib/python3.13/site-packages (from pydantic>=2.9->ollama) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.13/site-packages (from pydantic>=2.9->ollama) (0.4.2)

# %%
import os
from ollama import Client

client = Client(
    host="https://ollama.com",
    headers={'Authorization': 'Bearer ' + os.environ.get('OLLAMA_API_KEY')}
)

messages = [
  {
    'role': 'user',
    'content': 'Why is the sky blue?',
  },
]

for part in client.chat('gpt-oss:120b', messages=messages, stream=True):
  print(part['message']['content'], end='', flush=True)
# Out:
# **Short answer:**
# The sky looks blue because the atmosphere scatters short‑wavelength (blue) sunlight much more efficiently than it scatters longer‑wavelength (red) light. Our eyes then see the scattered blue light coming from every direction.
#
# ---
#
# ## The physics behind the colour
#
# 1. **Sunlight is a mix of colours**
#    Sunlight is (to a good approximation) white light – a blend of all visible wavelengths, from about 380 nm (violet) to 750 nm (red).
#
# 2. **When sunlight meets the atmosphere…**
#    The air is filled with molecules (nitrogen, oxygen, a little argon, etc.) and tiny particles. When photons hit these tiny scatterers, they are redirected in many directions.
#
# 3. **Rayleigh scattering**
#    For particles **much smaller** than the wavelength of light (like individual gas molecules), the scattering follows *Rayleigh’s law*:
#
#    \[
#    I_{\text{scattered}} \propto \frac{1}{\lambda^{4}}
#    \]
#
#    – **Intensity drops with the fourth power of wavelength.**
#    – Blue light (λ ≈ 450 nm) is scattered about **10 times more** than green (λ ≈ 550 nm) and **~100 times more** than red (λ ≈ 650 nm).
#
# 4. **Why not violet?**
#    - The atmosphere does scatter violet even more than blue, but our eyes are **less sensitive** to violet, and a lot of violet is absorbed by the upper ozone layer.
#    - The brain also “tags” the scattered light it receives as “blue” because that’s the dominant wavelength after the violet contribution is filtered out.
#
# 5. **Result:**
#    The direct line of sight to the Sun is still largely white (the Sun itself looks yellowish because a tiny bit of the blue has been scattered out).
#    The sky *around* the Sun, however, is filled with the preferentially scattered blue light, so we perceive the whole dome as blue.
#
# ---
#
# ## Why the colour changes at sunrise and sunset
#
# - When the Sun is low on the horizon, its light must travel through **much more atmosphere** (up to 40 times the vertical path length).
# - The extra distance gives the short‑wavelength light even more chances to be scattered out of the direct beam, leaving a higher proportion of **red and orange** wavelengths to reach our eyes.
# - The scattered light that does reach us from the sky is then tinged with reds and pinks, producing beautiful sunrise/sunset colours.
#
# ---
#
# ## Quick analogies
#
# | Phenomenon | What it shows |
# |------------|----------------|
# | **A foggy street lamp at night** | Fog droplets are *much larger* than air molecules, so they scatter all wavelengths equally (Mie scattering). The lamp looks **white** or **yellow**, not blue. |
# | **A clear blue lake** | Water itself doesn’t scatter much; the blue you see is mainly reflected sky light – the same reason the sky looks blue. |
# | **Why the ocean can appear green or turquoise** | Besides scattering, dissolved organic matter and suspended particles selectively absorb or scatter certain wavelengths, altering the colour. |
#
# ---
#
# ## Bottom line
#
# - **Rayleigh scattering** → stronger for short wavelengths → blue dominates the diffuse skylight.
# - Human eyes are most sensitive to blue and less to violet, so we *see* the sky as blue.
#
# That’s why, on a clear day, when you look up, you are essentially looking at a vast, thin layer of blue‑tinted sunlight scattered by the gases in our atmosphere.

# %%
from ollama import chat

stream = chat(
    model='kimi-k2.5:cloud',
    messages=[{'role': 'user', 'content': 'What is 17 × 23?'}],
    stream=True
)

in_thinking = False
content = ''
thinking = ''

for chunk in stream:
    if chunk.message.thinking:
        if not in_thinking:
            in_thinking = True
            print('Thinking:\n', end='', flush=True)
        print(chunk.message.thinking, end='', flush=True)

        thinking += chunk.message.thinking
    
    elif chunk.message.content:
        if in_thinking:
            in_thinking = False
            print('\n\nAnswer:\n', end='', flush=True)
        print(chunk.message.content, end='', flush=True)

        content += chunk.message.content

    new_messages = [
        {'role': 'assistant', 'thinking': thinking, 'content': content}
    ]
# Out:
# Thinking:
#  The user is asking for the product of 17 and 23.
#
# I can calculate this in a few ways:
#
# Method 1: Standard multiplication
# 17 × 23 = 17 × (20 + 3) = 17 × 20 + 17 × 3 = 340 + 51 = 391
#
# Method 2: Difference of squares approach
# 17 × 23 = (20 - 3) × (20 + 3) = 20² - 3² = 400 - 9 = 391
#
# Method 3: Direct multiplication
# 17 × 23:
# 7 × 3 = 21 (write 1, carry 2)
# 7 × 2 = 14 + 2 = 16
# 1 × 3 = 3
# 1 × 2 = 2
#
# So:
#   17
# × 23
# ----
#   51  (17 × 3)
#  340  (17 × 20)
# ----
#  391
#
# All methods give 391.
#
# Let me verify: 23 × 17 should be the same.
# 23 × 10 = 230
# 23 × 7 = 161
# 230 + 161 = 391
#
# Yes, correct.
#
# Answer:
#  17 × 23 = **391**
#
# Here's one way to calculate it:
# - 17 × 20 = 340
# - 17 × 3 = 51
# - 340 + 51 = **391**
#
# Or using the difference of squares: (20 - 3)(20 + 3) = 400 - 9 = **391**

# %%
stream = chat(
    model='kimi-k2.5:cloud',
    messages=[{'role': 'user', 'content': 'What is 17 × 23?'}],
    stream=True
)

for chunk in stream:
    print(chunk.message)
# Out:
# role='assistant' content='' thinking=' This' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' is' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' a' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' straightforward' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' multiplication' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' problem' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=':' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='17' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ×' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='23' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='.\n\n' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='Let' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' me' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' calculate' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' it' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=':\n' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='17' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ×' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='23' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' =' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ?' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='\n\n' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='I' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' can' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' use' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' the' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' standard' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' multiplication' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' method' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=':\n' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='17' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ×' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='23' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' =' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='17' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ×' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' (' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='20' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' +' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='3' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=')' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' =' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='17' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ×' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='20' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' +' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='17' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ×' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='3' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='\n' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='17' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ×' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='20' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' =' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='340' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='\n' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='17' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ×' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='3' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' =' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='51' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='\n' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='340' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' +' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='51' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' =' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='391' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='\n\n' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='Alternatively' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=',' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' I' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' can' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' use' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' the' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' fact' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' that' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' (' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='20' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' -' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='3' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=')' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ×' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' (' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='20' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' +' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='3' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=')' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' =' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='20' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='²' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' -' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='3' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='²' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' =' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='400' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' -' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='9' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' =' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='391' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=',' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' but' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' wait' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=',' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=" that's" images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' not' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' right' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' because' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='17' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' =' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='20' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' -' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='3' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=',' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' but' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='23' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' =' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='20' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' +' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='3' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='.' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' \n' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='So' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' yes' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=':' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='17' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ×' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='23' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' =' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' (' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='20' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' -' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='3' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=')(' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='20' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' +' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='3' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=')' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' =' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='20' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='²' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' -' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='3' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='²' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' =' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='400' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' -' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='9' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' =' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='391' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='.\n\n' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='Let' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' me' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' verify' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=':\n' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='17' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='\n' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='×' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='23' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='\n' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='-----\n' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='51' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' (' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='17' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ×' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='3' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=')\n' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='340' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' (' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='17' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ×' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='20' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=')\n' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='-----\n' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='391' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='\n\n' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='Yes' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=',' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' the' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' answer' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' is' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=' ' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='391' images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking='.' images=None tool_name=None tool_calls=None
# role='assistant' content=' 17' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' ×' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' ' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='23' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' =' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' **' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='391' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='**\n\n' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content="Here's" thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' one' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' way' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' to' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' calculate' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' it' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=':\n' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='-' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' ' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='17' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' ×' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' ' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='20' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' =' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' ' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='340' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='\n' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='-' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' ' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='17' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' ×' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' ' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='3' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' =' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' ' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='51' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='\n' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='-' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' ' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='340' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' +' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' ' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='51' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' =' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' **' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='391' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='**\n\n' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='Alternatively' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=',' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' using' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' the' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' difference' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' of' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' squares' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' formula' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=':' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' \n' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='(' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='20' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' -' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' ' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='3' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=')(' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='20' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' +' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' ' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='3' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=')' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' =' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' ' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='20' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='²' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' -' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' ' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='3' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='²' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' =' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' ' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='400' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' -' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' ' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='9' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' =' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content=' **' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='391' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='**' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=None images=None tool_name=None tool_calls=None
# role='assistant' content='' thinking=None images=None tool_name=None tool_calls=None

# %%
new_messages
# Out:
# [{'role': 'assistant',
#   'thinking': ' The user is asking for the product of 17 and 23.\n\nI can calculate this in a few ways:\n\nMethod 1: Standard multiplication\n17 × 23 = 17 × (20 + 3) = 17 × 20 + 17 × 3 = 340 + 51 = 391\n\nMethod 2: Difference of squares approach\n17 × 23 = (20 - 3) × (20 + 3) = 20² - 3² = 400 - 9 = 391\n\nMethod 3: Direct multiplication\n17 × 23:\n7 × 3 = 21 (write 1, carry 2)\n7 × 2 = 14 + 2 = 16\n1 × 3 = 3\n1 × 2 = 2\n\nSo:\n  17\n× 23\n----\n  51  (17 × 3)\n 340  (17 × 20)\n----\n 391\n\nAll methods give 391.\n\nLet me verify: 23 × 17 should be the same.\n23 × 10 = 230\n23 × 7 = 161\n230 + 161 = 391\n\nYes, correct.',
#   'content': " 17 × 23 = **391**\n\nHere's one way to calculate it:\n- 17 × 20 = 340\n- 17 × 3 = 51\n- 340 + 51 = **391**\n\nOr using the difference of squares: (20 - 3)(20 + 3) = 400 - 9 = **391**"}]

# %% [markdown]
# ### Thinking models in Ollama (Python)

# %%
response = chat(
    model='kimi-k2.5:cloud',
    messages=[{'role': 'user', 'content': 'How many letter r are in strawberry?'}],
    think=True,
    stream=False
)

print('Thinking:\n', response.message.thinking)
print('\nAnswer:\n', response.message.content)
# Out:
# Thinking:
#   The user is asking how many times the letter "r" appears in the word "strawberry".
#
# Let me count:
# s-t-r-a-w-b-e-r-r-y
#
# 1. s - not r
# 2. t - not r
# 3. r - yes (1)
# 4. a - not r
# 5. w - not r
# 6. b - not r
# 7. e - not r
# 8. r - yes (2)
# 9. r - yes (3)
# 10. y - not r
#
# So there are 3 letter "r"s in "strawberry".
#
# Wait, let me double-check:
# s-t-r-a-w-b-e-r-r-y
# Positions:
# - 3rd letter: r
# - 8th letter: r
# - 9th letter: r
#
# Yes, 3 r's.
#
# Answer:
#   There are **3** letter "r"s in "strawberry":
#
# **S-t-r-a-w-b-e-r-r-y**
#
# 1. 3rd letter: **r**
# 2. 8th letter: **r**
# 3. 9th letter: **r**

# %% [markdown]
# ### Stream the reasoning trace
#
# Thinking streams interleave reasoning tokens before answer tokens. Detect the first thinking chunk to render a “thinking” section, then switch to the final reply once message.content arrives.

# %%
stream = chat(
    model='kimi-k2.5:cloud',
    messages=[{'role': 'user', 'content': 'How many letter r are in strawberry?'}],
    think=True,
    stream=True
)

in_thinking = False

for chunk in stream:
    if chunk.message.thinking and not in_thinking:
        in_thinking = True
        print('Thinking:\n', end='', flush=True)

    if chunk.message.thinking:
        print(chunk.message.thinking, end='', flush=True)

    elif chunk.message.content:
        if in_thinking:
            in_thinking = False
            print('\n\nAnswer:\n', end='', flush=True)
        print(chunk.message.content, end='', flush=True)
# Out:
# Thinking:
#  The user is asking how many times the letter "r" appears in the word "strawberry".
#
# Let me spell it out: s-t-r-a-w-b-e-r-r-y
#
# Position by position:
# 1. s
# 2. t
# 3. r (1st r)
# 4. a
# 5. w
# 6. b
# 7. e
# 8. r (2nd r)
# 9. r (3rd r)
# 10. y
#
# So there are 3 letter r's in "strawberry".
#
# Wait, let me double-check:
# s - no
# t - no
# r - yes (1)
# a - no
# w - no
# b - no
# e - no
# r - yes (2)
# r - yes (3)
# y - no
#
# Yes, 3 r's total.
#
# Answer:
#  There are **3** letter "r"s in the word "strawberry":
#
# **st**r**awbe**rr**y**

# %% [markdown]
# ### Structured Outputs

# %%
response = chat(
  model='kimi-k2.5:cloud',
  messages=[{'role': 'user', 'content': 'Tell me about Canada.'}],
  format='json'
)
print(response.message.content)
# Out:
#  Canada is the second-largest country in the world by land area (after Russia) and one of the most diverse nations culturally, geographically, and climatically. Here's an overview:
#
# ## **Basic Facts**
# - **Capital:** Ottawa (not Toronto or Vancouver, which are larger)
# - **Population:** Approximately 40 million people (highly urbanized, with about 80% living within 100km of the U.S. border)
# - **Official Languages:** English and French (French is the majority language in Quebec)
# - **Currency:** Canadian dollar (CAD)
# - **Government:** Federal parliamentary democracy and constitutional monarchy (King Charles III is head of state, represented federally by the Governor General)
#
# ## **Geography & Climate**
# Spanning nearly 10 million square kilometers, Canada features:
# - **Massive wilderness:** Boreal forests, the Canadian Shield (ancient rock), three coastlines (Atlantic, Pacific, Arctic), and the world's longest coastline
# - **Mountains:** The Rocky Mountains, Coast Mountains, and Laurentians
# - **Lakes:** Contains about 20% of the world's freshwater, including the Great Lakes (shared with the U.S.)
# - **Climate:** Ranges from temperate rainforests (British Columbia) to humid continental (Toronto/Montreal) to Arctic tundra (Northern territories). Winters are famously cold in most regions, though Vancouver and Victoria have mild, wet climates.
#
# ## **History**
# - **Indigenous peoples:** Inhabited the land for millennia (First Nations, Métis, and Inuit), comprising over 600 recognized bands with diverse languages and cultures
# - **Colonization:** French established the first permanent settlement (1608 in Quebec); British control expanded after the Seven Years' War (1763)
# - **Confederation:** Formed in 1867 with four provinces; gradually expanded to 10 provinces and 3 territories
# - **Evolution:** Gradual independence from Britain (still a Commonwealth realm), with the Constitution Act patriated in 1982
#
# ## **Society & Culture**
# - **Multiculturalism:** Official policy since 1971; Toronto is one of the world's most diverse cities, with over half its residents born outside Canada
# - **Bilingualism:** French-English duality is constitutionally protected; Quebec maintains distinct civil law tradition and cultural protections
# - **Values:** Generally associated with politeness, progressive social policies (universal healthcare since the 1960s), environmental consciousness, and peacekeeping
# - **Indigenous reconciliation:** Ongoing process addressing historical injustices, residential schools, and land rights
#
# ## **Economy**
# - **Resource-based:** Major exporter of oil, natural gas, lumber, minerals, and agricultural products
# - **Advanced sectors:** Strong in aerospace, automotive manufacturing, technology (AI hub in Toronto, tech sector in Vancouver), and financial services
# - **Trade:** Highly dependent on trade with the U.S. (about 75% of exports), though diversifying toward Asia and Europe
# - **Quality of life:** Consistently ranks high in human development indices, though housing affordability has become a major issue in major cities
#
# ## **Notable Characteristics**
# - **Sports:** Ice hockey is culturally dominant (invented in Canada), but lacrosse is the official summer sport
# - **Wildlife:** Home to moose, polar bears, grizzly bears, beavers (national symbol), and abundant marine life
# - **Food:** Poutine (Quebec), butter tarts, Nanaimo bars, Caesar cocktails (clamato-based), and strong coffee culture (Tim Hortons)
# - **Innovation:** Invented insulin, basketball, the telephone (Bell), IMAX, and the Canadarm for space shuttles
#
# ## **Major Cities**
# - **Toronto:** Financial capital, most populous, ultra-diverse
# - **Montreal:** Cultural capital, largest French-speaking city outside France
# - **Vancouver:** Pacific gateway, rainforests and mountains, expensive real estate
# - **Calgary/Edmonton:** Energy sector hubs in Alberta
# - **Quebec City:** Historic walled city, UNESCO site
#
# **Challenges facing Canada today** include reconciliation with Indigenous peoples, housing affordability crises in major cities, climate change impacts on the Arctic and forests, and maintaining unity between its distinct regions.
#
# Would you like me to elaborate on any specific aspect—such as visiting as a tourist, immigration, Canadian politics, or a particular region?

# %%
from pydantic import BaseModel

class Country(BaseModel):
    name: str
    capital: str
    languages: list[str]


response = chat(
    model='kimi-k2.5:cloud',
    messages=[{'role':'user', 'content':'Tell me about Canada.'}],
    format=Country.model_json_schema(),
    stream=False
)

country = Country.model_validate_json(response.message.content)
print(country)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[9], line 15
#       6     languages: list[str]
#       9 response = chat(
#      10     model='kimi-k2.5:cloud',
#      11     messages=[{'role':'user', 'content':'Tell me about Canada.'}],
#      12     format=Country.model_json_schema(),
#      13 )
# ---> 15 country = Country.model_validate_json(response.message.content)
#      16 print(country)
#
# File ~/ollama-work/.venv/lib/python3.13/site-packages/pydantic/main.py:766, in BaseModel.model_validate_json(cls, json_data, strict, extra, context, by_alias, by_name)
#     760 if by_alias is False and by_name is not True:
#     761     raise PydanticUserError(
#     762         'At least one of `by_alias` or `by_name` must be set to True.',
#     763         code='validate-by-alias-and-name-false',
#     764     )
# --> 766 return cls.__pydantic_validator__.validate_json(
#     767     json_data, strict=strict, extra=extra, context=context, by_alias=by_alias, by_name=by_name
#     768 )
#
# ValidationError: 1 validation error for Country
#   Invalid JSON: expected value at line 1 column 2 [type=json_invalid, input_value=' Canada is the world\'s ...rent political climate?', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.12/v/json_invalid
